# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd

navegador = webdriver.Chrome()
navegador.get("https://steamcommunity.com/market/search?appid=730")
total_paginas = int(navegador.find_element_by_xpath('//*[@id="searchResults_links"]/span[7]').text)

name =[] 
price = []
for i in range(1,3):
    time.sleep(1)
    for i in range (0,10):
        name.append(str(navegador.find_element_by_id(f'result_{i}_name').text))
        price.append(0.01*(int(navegador.find_element_by_xpath(f'//*[@id="result_{i}"]/div[1]/div[2]/span[1]/span[1]').get_attribute('data-price'))))
    navegador.find_element_by_xpath('//*[@id="searchResults_btn_next"]').click()
navegador.quit()

itens_df = pd.DataFrame(list(zip(name,price)),columns=['Nome','Preço USD$'])
# Get informations of CSGO itens from the steam website (name and price)
# Out:
#                                                  Nome  Preço USD$
# 17                                 2ª Caixa Cromática        0.36
# 5                                  2ª Caixa Espectral        0.35
# 3                                       2ª Caixa Gama        0.46
# 14        AK-47 | Linhas Vermelhas (Testada em Campo)       15.00
# 13           AK-47 | Tons de Preto (Testada em Campo)        5.25
# 7                 Adesivo | Onça-facada (Holográfico)        0.34
# 11                                    Caixa Espectral        0.73
# 8                                     Caixa Fraturada        0.15
# 9                    Caixa da Operação Presa Quebrada        0.50
# 12                            Caixa da Zona de Perigo        0.08
# 1                                     Caixa das Luvas        1.69
# 15                   Caixa de Armas da Operação Fênix        1.05
# 2               Caixa de Armas da Operação Libertação        2.44
# 4                                     Caixa do Aperto        0.18
# 19                                 Caixa do Horizonte        0.11
# 16                  Desafiantes Regionais da CRM 2020        0.32
# 18  Desert Eagle | Cadeia de Caracteres (Pouco Usada)       83.64
# 6                                  Lendas da CRM 2020        0.41
# 10  MP7 | Reconhecimento Militar (Veterana de Guerra)        0.04
# 0                                      Snakebite Case        0.58

# %%
itens_temp=dict()
navegador = webdriver.Chrome()
navegador.get("https://steamcommunity.com/market/search?appid=730")
while True:
    for i in range(1,3):
        time.sleep(1)
        for i in range (0,10):
            itens_temp[(str(navegador.find_element_by_id(f'result_{i}_name').text))] = (0.01*(int(navegador.find_element_by_xpath(f'//*[@id="result_{i}"]/div[1]/div[2]/span[1]/span[1]').get_attribute('data-price'))))
        navegador.find_element_by_xpath('//*[@id="searchResults_btn_next"]').click()
    navegador.quit()

    itens_df['Preço Atualizado'] = [itens_temp[resp] for resp in itens_df.Nome]
    time.sleep(60)
    display(itens_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-56c450eeb1d2> in <module>
#       1 itens_temp=dict()
# ----> 2 navegador = webdriver.Chrome()
#       3 navegador.get("https://steamcommunity.com/market/search?appid=730")
#       4 while True:
#       5     for i in range(1,3):
#
# NameError: name 'webdriver' is not defined

# %%
itens_df['Preço Atualizado'] = [itens_temp[resp] for resp in itens_df.Nome]

# %%
display(itens_df)
# import pywhatkit as kt

# kt.sendwhatmsg_instantly("+553185674356","  ")
# # Send Alert by Whatsapp
# Out:
#                                                  Nome  Preço USD$  \
# 0                                      Snakebite Case        0.58
# 1                                     Caixa das Luvas        1.69
# 2               Caixa de Armas da Operação Libertação        2.44
# 3                                       2ª Caixa Gama        0.46
# 4                                     Caixa do Aperto        0.18
# 5                                  2ª Caixa Espectral        0.35
# 6                                  Lendas da CRM 2020        0.41
# 7                 Adesivo | Onça-facada (Holográfico)        0.34
# 8                                     Caixa Fraturada        0.15
# 9                    Caixa da Operação Presa Quebrada        0.50
# 10  MP7 | Reconhecimento Militar (Veterana de Guerra)        0.04
# 11                                    Caixa Espectral        0.73
# 12                            Caixa da Zona de Perigo        0.08
# 13           AK-47 | Tons de Preto (Testada em Campo)        5.25
# 14        AK-47 | Linhas Vermelhas (Testada em Campo)       15.00
# 15                   Caixa de Armas da Operação Fênix        1.05
# 16                  Desafiantes Regionais da CRM 2020        0.32
# 17                                 2ª Caixa Cromática        0.36
# 18  Desert Eagle | Cadeia de Caracteres (Pouco Usada)       83.64
# 19                                 Caixa do Horizonte        0.11
#
#     Preço Atualizado
# 0               0.61
# 1               1.69
# 2               2.43
# 3               0.46
# 4               0.18
# 5               0.37
# 6               0.41
# 7               0.34
# 8               0.16
# 9               0.50
# 10              0.04
# 11              0.69
# 12              0.08
# 13              5.61
# 14             15.00
# 15              1.05
# 16              0.32
# 17              0.34
# 18             84.73
# 19              0.11
